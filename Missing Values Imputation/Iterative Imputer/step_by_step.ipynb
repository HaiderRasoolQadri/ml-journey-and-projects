# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('50_Startups.csv')
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df = np.round(pd.read_csv('50_Startups.csv')[['R&D Spend','Administration','Marketing Spend','Profit']]/10000)
df.shape
# Out:
# (50, 4)

# %%
df.sample(4)
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit
# 1        16.0            15.0             44.0    19.0
# 15       11.0            12.0             26.0    13.0
# 29        7.0            15.0             11.0    10.0
# 17        9.0            15.0             28.0    13.0

# %%
df = df.iloc[:,0:-1]

# %%
# Adding missing values
df.iloc[1,0] = np.NaN
df.iloc[3,1] = np.NaN
df.iloc[-1,-1] = np.NaN

# %%
# Step 1 - Impute all missing values with mean of respective col

df0 = pd.DataFrame()

df0['R&D Spend'] = df['R&D Spend'].fillna(df['R&D Spend'].mean())
df0['Administration'] = df['Administration'].fillna(df['Administration'].mean())
df0['Marketing Spend'] = df['Marketing Spend'].fillna(df['Marketing Spend'].mean())

# %%
# 0th iteration
df0.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0  17.000000       14.000000             47.0
# 1   7.163265       15.000000             44.0
# 2  15.000000       10.000000             41.0
# 3  14.000000       12.163265             38.0
# 4  14.000000        9.000000             37.0

# %%
# Remove the col1 imputed value
df1 = df0.copy()

df1.iloc[1,0] = np.NaN

df1.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0       17.0       14.000000             47.0
# 1        NaN       15.000000             44.0
# 2       15.0       10.000000             41.0
# 3       14.0       12.163265             38.0
# 4       14.0        9.000000             37.0

# %%
# Use 4 rows to build a model and use the last for prediction

X = df1.iloc[[0,2,3,4],1:3]
X
# Out:
#    Administration  Marketing Spend
# 0       14.000000             47.0
# 2       10.000000             41.0
# 3       12.163265             38.0
# 4        9.000000             37.0

# %%
y = df1.iloc[[0,2,3,4],0]
y
# Out:
# 0    17.0
# 2    15.0
# 3    14.0
# 4    14.0
# Name: R&D Spend, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X,y)
lr.predict(df1.iloc[1,1:].values.reshape(1,2))
# Out:
# array([15.90294324])

# %%
df1.iloc[1,0] = 15.90294324

# %%
df1.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0  17.000000       14.000000             47.0
# 1  15.902943       15.000000             44.0
# 2  15.000000       10.000000             41.0
# 3  14.000000       12.163265             38.0
# 4  14.000000        9.000000             37.0

# %%
# Remove the col2 imputed value

df1.iloc[3,1] = np.NaN

df1.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0  17.000000            14.0             47.0
# 1  15.902943            15.0             44.0
# 2  15.000000            10.0             41.0
# 3  14.000000             NaN             38.0
# 4  14.000000             9.0             37.0

# %%
# Use other rows to build a model and use the first for prediction
X = df1.iloc[[0,1,2,4],[0,2]]
X
# Out:
#    R&D Spend  Marketing Spend
# 0  17.000000             47.0
# 1  15.902943             44.0
# 2  15.000000             41.0
# 4  14.000000             37.0

# %%
y = df1.iloc[[0,1,2,4],1]
y
# Out:
# 0    14.0
# 1    15.0
# 2    10.0
# 4     9.0
# Name: Administration, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X,y)
lr.predict(df1.iloc[3,[0,2]].values.reshape(1,2))
# Out:
# array([10.14874768])

# %%
df1.iloc[3,1] = 10.14874768

# %%
df1.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0  17.000000       14.000000             47.0
# 1  15.902943       15.000000             44.0
# 2  15.000000       10.000000             41.0
# 3  14.000000       10.148748             38.0
# 4  14.000000        9.000000             37.0

# %%
# Remove the col3 imputed value
df1.iloc[4,-1] = np.NaN

df1.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0  17.000000       14.000000             47.0
# 1  15.902943       15.000000             44.0
# 2  15.000000       10.000000             41.0
# 3  14.000000       10.148748             38.0
# 4  14.000000        9.000000              NaN

# %%
# Use last 3 rows to build a model and use the first for prediction
X = df1.iloc[0:4,0:2]
X
# Out:
#    R&D Spend  Administration
# 0  17.000000       14.000000
# 1  15.902943       15.000000
# 2  15.000000       10.000000
# 3  14.000000       10.148748

# %%
y = df1.iloc[0:4,-1]
y
# Out:
# 0    47.0
# 1    44.0
# 2    41.0
# 3    38.0
# Name: Marketing Spend, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X,y)
lr.predict(df1.iloc[4,0:2].values.reshape(1,2))
# Out:
# array([37.96193327])

# %%
df1.iloc[4,-1] = 37.96193327

# %%
# After 1st Iteration
df1.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0  17.000000       14.000000        47.000000
# 1  15.902943       15.000000        44.000000
# 2  15.000000       10.000000        41.000000
# 3  14.000000       10.148748        38.000000
# 4  14.000000        9.000000        37.961933

# %%
# Subtract 0th iteration from 1st iteration
df1 - df0
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0    0.000000        0.000000         0.000000
# 1    8.739678        0.000000         0.000000
# 2    0.000000        0.000000         0.000000
# 3    0.000000       -2.014518         0.000000
# 4    0.000000        0.000000         0.961933
# 5    0.000000        0.000000         0.000000
# 6    0.000000        0.000000         0.000000
# 7    0.000000        0.000000         0.000000
# 8    0.000000        0.000000         0.000000
# 9    0.000000        0.000000         0.000000
# 10   0.000000        0.000000         0.000000
# 11   0.000000        0.000000         0.000000
# 12   0.000000        0.000000         0.000000
# 13   0.000000        0.000000         0.000000
# 14   0.000000        0.000000         0.000000
# 15   0.000000        0.000000         0.000000
# 16   0.000000        0.000000         0.000000
# 17   0.000000        0.000000         0.000000
# 18   0.000000        0.000000         0.000000
# 19   0.000000        0.000000         0.000000
# 20   0.000000        0.000000         0.000000
# 21   0.000000        0.000000         0.000000
# 22   0.000000        0.000000         0.000000
# 23   0.000000        0.000000         0.000000
# 24   0.000000        0.000000         0.000000
# 25   0.000000        0.000000         0.000000
# 26   0.000000        0.000000         0.000000
# 27   0.000000        0.000000         0.000000
# 28   0.000000        0.000000         0.000000
# 29   0.000000        0.000000         0.000000
# 30   0.000000        0.000000         0.000000
# 31   0.000000        0.000000         0.000000
# 32   0.000000        0.000000         0.000000
# 33   0.000000        0.000000         0.000000
# 34   0.000000        0.000000         0.000000
# 35   0.000000        0.000000         0.000000
# 36   0.000000        0.000000         0.000000
# 37   0.000000        0.000000         0.000000
# 38   0.000000        0.000000         0.000000
# 39   0.000000        0.000000         0.000000
# 40   0.000000        0.000000         0.000000
# 41   0.000000        0.000000         0.000000
# 42   0.000000        0.000000         0.000000
# 43   0.000000        0.000000         0.000000
# 44   0.000000        0.000000         0.000000
# 45   0.000000        0.000000         0.000000
# 46   0.000000        0.000000         0.000000
# 47   0.000000        0.000000         0.000000
# 48   0.000000        0.000000         0.000000
# 49   0.000000        0.000000         0.000000

# %%
df2 = df1.copy()

df2.iloc[1,0] = np.NaN

df2.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0       17.0       14.000000        47.000000
# 1        NaN       15.000000        44.000000
# 2       15.0       10.000000        41.000000
# 3       14.0       10.148748        38.000000
# 4       14.0        9.000000        37.961933

# %%
X = df2.iloc[[0,2,3,4],1:3]
y = df2.iloc[[0,2,3,4],0]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df2.iloc[1,1:].values.reshape(1,2))
# Out:
# array([15.9939676])

# %%
df2.iloc[1,0] = 15.9939676

# %%
df2.iloc[3,1] = np.NaN
X = df2.iloc[[0,1,2,4],[0,2]]
y = df2.iloc[[0,1,2,4],1]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df2.iloc[3,[0,2]].values.reshape(1,2))
# Out:
# array([10.13176918])

# %%
df2.iloc[3,1] = 10.13176918

# %%
df2.iloc[4,-1] = np.NaN

X = df2.iloc[0:4,0:2]
y = df2.iloc[0:4,-1]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df2.iloc[4,0:2].values.reshape(1,2))
# Out:
# array([37.99757961])

# %%
df2.iloc[4,-1] = 37.99757961

# %%
df2.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0  17.000000       14.000000         47.00000
# 1  15.993968       15.000000         44.00000
# 2  15.000000       10.000000         41.00000
# 3  14.000000       10.131769         38.00000
# 4  14.000000        9.000000         37.99758

# %%
df2 - df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0    0.000000        0.000000         0.000000
# 1    0.091024        0.000000         0.000000
# 2    0.000000        0.000000         0.000000
# 3    0.000000       -0.016979         0.000000
# 4    0.000000        0.000000         0.035646
# 5    0.000000        0.000000         0.000000
# 6    0.000000        0.000000         0.000000
# 7    0.000000        0.000000         0.000000
# 8    0.000000        0.000000         0.000000
# 9    0.000000        0.000000         0.000000
# 10   0.000000        0.000000         0.000000
# 11   0.000000        0.000000         0.000000
# 12   0.000000        0.000000         0.000000
# 13   0.000000        0.000000         0.000000
# 14   0.000000        0.000000         0.000000
# 15   0.000000        0.000000         0.000000
# 16   0.000000        0.000000         0.000000
# 17   0.000000        0.000000         0.000000
# 18   0.000000        0.000000         0.000000
# 19   0.000000        0.000000         0.000000
# 20   0.000000        0.000000         0.000000
# 21   0.000000        0.000000         0.000000
# 22   0.000000        0.000000         0.000000
# 23   0.000000        0.000000         0.000000
# 24   0.000000        0.000000         0.000000
# 25   0.000000        0.000000         0.000000
# 26   0.000000        0.000000         0.000000
# 27   0.000000        0.000000         0.000000
# 28   0.000000        0.000000         0.000000
# 29   0.000000        0.000000         0.000000
# 30   0.000000        0.000000         0.000000
# 31   0.000000        0.000000         0.000000
# 32   0.000000        0.000000         0.000000
# 33   0.000000        0.000000         0.000000
# 34   0.000000        0.000000         0.000000
# 35   0.000000        0.000000         0.000000
# 36   0.000000        0.000000         0.000000
# 37   0.000000        0.000000         0.000000
# 38   0.000000        0.000000         0.000000
# 39   0.000000        0.000000         0.000000
# 40   0.000000        0.000000         0.000000
# 41   0.000000        0.000000         0.000000
# 42   0.000000        0.000000         0.000000
# 43   0.000000        0.000000         0.000000
# 44   0.000000        0.000000         0.000000
# 45   0.000000        0.000000         0.000000
# 46   0.000000        0.000000         0.000000
# 47   0.000000        0.000000         0.000000
# 48   0.000000        0.000000         0.000000
# 49   0.000000        0.000000         0.000000

# %%
df3 = df2.copy()

df3.iloc[1,0] = np.NaN

df3.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0       17.0       14.000000         47.00000
# 1        NaN       15.000000         44.00000
# 2       15.0       10.000000         41.00000
# 3       14.0       10.131769         38.00000
# 4       14.0        9.000000         37.99758

# %%
X = df3.iloc[[0,2,3,4],1:3]
y = df3.iloc[[0,2,3,4],0]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df3.iloc[1,1:].values.reshape(1,2))
# Out:
# array([15.99960587])

# %%
df3.iloc[1,0] = 15.99960587

# %%
df3.iloc[3,1] = np.NaN
X = df3.iloc[[0,1,2,4],[0,2]]
y = df3.iloc[[0,1,2,4],1]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df3.iloc[3,[0,2]].values.reshape(1,2))
# Out:
# array([10.12716602])

# %%
df3.iloc[3,1] = 10.12716602

# %%
df3.iloc[4,-1] = np.NaN

X = df3.iloc[0:4,0:2]
y = df3.iloc[0:4,-1]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df3.iloc[4,0:2].values.reshape(1,2))
# Out:
# array([37.99984235])

# %%
df3.iloc[4,-1] = 37.99984235

# %%
df3.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0  17.000000       14.000000        47.000000
# 1  15.999606       15.000000        44.000000
# 2  15.000000       10.000000        41.000000
# 3  14.000000       10.127166        38.000000
# 4  14.000000        9.000000        37.999842

# %%
df3 - df2
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0    0.000000        0.000000         0.000000
# 1    0.005638        0.000000         0.000000
# 2    0.000000        0.000000         0.000000
# 3    0.000000       -0.004603         0.000000
# 4    0.000000        0.000000         0.002263
# 5    0.000000        0.000000         0.000000
# 6    0.000000        0.000000         0.000000
# 7    0.000000        0.000000         0.000000
# 8    0.000000        0.000000         0.000000
# 9    0.000000        0.000000         0.000000
# 10   0.000000        0.000000         0.000000
# 11   0.000000        0.000000         0.000000
# 12   0.000000        0.000000         0.000000
# 13   0.000000        0.000000         0.000000
# 14   0.000000        0.000000         0.000000
# 15   0.000000        0.000000         0.000000
# 16   0.000000        0.000000         0.000000
# 17   0.000000        0.000000         0.000000
# 18   0.000000        0.000000         0.000000
# 19   0.000000        0.000000         0.000000
# 20   0.000000        0.000000         0.000000
# 21   0.000000        0.000000         0.000000
# 22   0.000000        0.000000         0.000000
# 23   0.000000        0.000000         0.000000
# 24   0.000000        0.000000         0.000000
# 25   0.000000        0.000000         0.000000
# 26   0.000000        0.000000         0.000000
# 27   0.000000        0.000000         0.000000
# 28   0.000000        0.000000         0.000000
# 29   0.000000        0.000000         0.000000
# 30   0.000000        0.000000         0.000000
# 31   0.000000        0.000000         0.000000
# 32   0.000000        0.000000         0.000000
# 33   0.000000        0.000000         0.000000
# 34   0.000000        0.000000         0.000000
# 35   0.000000        0.000000         0.000000
# 36   0.000000        0.000000         0.000000
# 37   0.000000        0.000000         0.000000
# 38   0.000000        0.000000         0.000000
# 39   0.000000        0.000000         0.000000
# 40   0.000000        0.000000         0.000000
# 41   0.000000        0.000000         0.000000
# 42   0.000000        0.000000         0.000000
# 43   0.000000        0.000000         0.000000
# 44   0.000000        0.000000         0.000000
# 45   0.000000        0.000000         0.000000
# 46   0.000000        0.000000         0.000000
# 47   0.000000        0.000000         0.000000
# 48   0.000000        0.000000         0.000000
# 49   0.000000        0.000000         0.000000
