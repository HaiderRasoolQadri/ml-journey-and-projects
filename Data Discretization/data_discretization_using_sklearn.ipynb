# %%
# import liberaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import KBinsDiscretizer

# %%
# load the dataset
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# check for missing values
df.isnull().sum().sort_values(ascending = False)
# Out:
# deck           688
# age            177
# embarked         2
# embark_town      2
# survived         0
# pclass           0
# sex              0
# sibsp            0
# parch            0
# fare             0
# class            0
# who              0
# adult_male       0
# alive            0
# alone            0
# dtype: int64

# %%
# first we need to impuet the missing values 
df['age'] = df['age'].fillna(df['age'].median())

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# calling discretizatior
age_discretizer = KBinsDiscretizer(n_bins = 5 , encode = 'ordinal', strategy = 'uniform')
fare_discretizer = KBinsDiscretizer(n_bins = 6 , encode = 'ordinal', strategy = 'uniform')

# %%
# fitting data in to discretizer
df['bined_age'] = age_discretizer.fit_transform(df[['age']])
df['bined_fare'] = fare_discretizer.fit_transform(df[['age']])

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  bined_age  bined_fare
# 0    man        True  NaN  Southampton    no  False        1.0         1.0
# 1  woman       False    C    Cherbourg   yes  False        2.0         2.0
# 2  woman       False  NaN  Southampton   yes   True        1.0         1.0
# 3  woman       False    C  Southampton   yes  False        2.0         2.0
# 4    man        True  NaN  Southampton    no   True        2.0         2.0

# %%
# how do we know that bining is done let's see graph
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

sns.histplot(df, x = 'age', hue = 'bined_age', ax=ax1, palette='viridis')
sns.histplot(df, x='fare', hue='bined_fare', ax=ax2)
plt.show()
